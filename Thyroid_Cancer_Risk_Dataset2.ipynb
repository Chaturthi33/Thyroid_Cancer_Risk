# %%
import pandas as pd
# load/read dataset
df=pd.read_csv("thyroid_cancer_risk_data.csv")
df
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %% [markdown]
# # Insights

# %% [markdown]
# # Rows: 212,691 records (patients)

# %% [markdown]
# # Columns: 17

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender  Country  Ethnicity Family_History  \
# 0           1   66    Male   Russia  Caucasian             No
# 1           2   29    Male  Germany   Hispanic             No
# 2           3   86    Male  Nigeria  Caucasian             No
# 3           4   75  Female    India      Asian             No
# 4           5   35  Female  Germany    African            Yes
#
#   Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  TSH_Level  \
# 0                Yes                No      No      No       No       9.37
# 1                Yes                No      No      No       No       1.83
# 2                 No                No      No      No       No       6.26
# 3                 No                No      No      No       No       4.10
# 4                Yes                No      No      No       No       9.10
#
#    T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk Diagnosis
# 0      1.67      6.16         1.08                 Low    Benign
# ...

# %% [markdown]
# # The first 5 rows display in thyroid cancer risk dataset

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Country', 'Ethnicity', 'Family_History',
#        'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
#        'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size',
#        'Thyroid_Cancer_Risk', 'Diagnosis'],
#       dtype='object')

# %% [markdown]
# # Insights
# .Patient_Id = Unique identifier.
# .Age = Age may correlate with gender,country,thyroid cancer,family_histor.
# .Gender = Male/Female
# .Country =
# .Ethnicity = Similar to Country
# .Family_History = Known risk factor
# .
# .Iodine_Deficiency = Affects thyroid hormone production
# .Smoking

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Patient_ID           212691 non-null  int64
#  1   Age                  212691 non-null  int64
#  2   Gender               212691 non-null  object
#  3   Country              212691 non-null  object
#  4   Ethnicity            212691 non-null  object
#  5   Family_History       212691 non-null  object
#  6   Radiation_Exposure   212691 non-null  object
#  7   Iodine_Deficiency    212691 non-null  object
#  8   Smoking              212691 non-null  object
#  9   Obesity              212691 non-null  object
#  10  Diabetes             212691 non-null  object
#  11  TSH_Level            212691 non-null  float64
#  12  T3_Level             212691 non-null  float64
#  13  T4_Level             212691 non-null  float64
# ...

# %% [markdown]
# # Insights
# Number of rows: 212,691
#
# Number of columns: 17
#
# Memory usage: About 27.6 MB
#
# Patient_ID (int64)
#
# Age (int64)
#
# TSH_Level, T3_Level, T4_Level, Nodule_Size (float64)
#
# Gender , Country , Ethnicity , Family_History , Radiation_Exposure ,Iodine_Deficiency ,Smoking ,Obesity ,Diabetes (objects)

# %%
df[df['Gender']=='Female'].shape[0]
# Out:
# 127527

# %% [markdown]
# # Insights:This returns the number of female patients in dataset

# %%
df['Diagnosis'].value_counts()
# Out:
# Benign       163196
# Malignant     49495
# Name: Diagnosis, dtype: int64

# %% [markdown]
# # Insights:Will return the count of each diagnosis category in  dataset

# %%
df['Thyroid_Cancer_Risk'].value_counts()
# Out:
# Low       108388
# Medium     72400
# High       31903
# Name: Thyroid_Cancer_Risk, dtype: int64

# %% [markdown]
# # Insights:Gives the distribution of patients  the risk levels (Low, Medium, High)

# %%
df['Diabetes'].value_counts()
# Out:
# No     170098
# Yes     42593
# Name: Diabetes, dtype: int64

# %% [markdown]
# # Returns the count of patients with and without diabetes in  dataset.

# %%
df['Obesity'].value_counts()
# Out:
# No     148805
# Yes     63886
# Name: Obesity, dtype: int64

# %% [markdown]
# # Returns the number of patients who are obese versus those who are not, based on the dataset.

# %%
df['Smoking'].value_counts()
# Out:
# No     170260
# Yes     42431
# Name: Smoking, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    127527
# Male       85164
# Name: Gender, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# India          42496
# China          31978
# Nigeria        31918
# Brazil         21413
# Russia         21297
# Japan          16867
# South Korea    14965
# UK             10642
# USA            10558
# Germany        10557
# Name: Country, dtype: int64

# %%
df['Ethnicity'].value_counts()
# Out:
# Caucasian         63669
# Asian             53261
# African           42414
# Hispanic          32012
# Middle Eastern    21335
# Name: Ethnicity, dtype: int64

# %%
df['Family_History'].value_counts()
# Out:
# No     148866
# Yes     63825
# Name: Family_History, dtype: int64

# %%
df['Radiation_Exposure'].value_counts()
# Out:
# No     180831
# Yes     31860
# Name: Radiation_Exposure, dtype: int64

# %%
df['Iodine_Deficiency'].value_counts()
# Out:
# No     159673
# Yes     53018
# Name: Iodine_Deficiency, dtype: int64

# %%
df['TSH_Level'].value_counts()
# Out:
# 9.90     281
# 6.53     265
# 8.79     258
# 1.41     258
# 5.56     257
#         ...
# 8.77     175
# 4.10     174
# 7.51     166
# 0.10     112
# 10.00    108
# Name: TSH_Level, Length: 991, dtype: int64

# %%
df['T3_Level'].value_counts()
# Out:
# 3.34    783
# 1.27    783
# 3.03    764
# 1.43    762
# 1.96    762
#        ...
# 2.04    649
# 3.27    647
# 1.29    641
# 0.50    374
# 3.50    323
# Name: T3_Level, Length: 301, dtype: int64

# %%
df['T4_Level'].value_counts()
# Out:
# 10.67    329
# 4.68     328
# 10.57    326
# 9.38     325
# 10.93    325
#         ...
# 8.55     240
# 11.59    234
# 4.78     229
# 4.50     145
# 12.00    124
# Name: T4_Level, Length: 751, dtype: int64

# %%
df['Nodule_Size'].value_counts()
# Out:
# 2.93    475
# 0.69    475
# 3.71    474
# 4.49    474
# 4.64    473
#        ...
# 1.68    378
# 2.04    369
# 1.57    368
# 0.00    196
# 5.00    190
# Name: Nodule_Size, Length: 501, dtype: int64

# %%
df.dtypes
# Out:
# Patient_ID                int64
# Age                       int64
# Gender                   object
# Country                  object
# Ethnicity                object
# Family_History           object
# Radiation_Exposure       object
# Iodine_Deficiency        object
# Smoking                  object
# Obesity                  object
# Diabetes                 object
# TSH_Level               float64
# T3_Level                float64
# T4_Level                float64
# Nodule_Size             float64
# Thyroid_Cancer_Risk    category
# Diagnosis               float64
# dtype: object

# %%
#Display null value are present in dataset
df.isna().sum()    #Returns a new DataFrame of the same shape as df, where each cell is:
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Country                0
# Ethnicity              0
# Family_History         0
# Radiation_Exposure     0
# Iodine_Deficiency      0
# Smoking                0
# Obesity                0
# Diabetes               0
# TSH_Level              0
# T3_Level               0
# T4_Level               0
# Nodule_Size            0
# Thyroid_Cancer_Risk    0
# Diagnosis              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()   #only numeric columns display
# Out:
#          Patient_ID            Age      TSH_Level       T3_Level  \
# count  212691.00000  212691.000000  212691.000000  212691.000000
# mean   106346.00000      51.918497       5.045102       2.001727
# std     61398.74739      21.632815       2.860264       0.866248
# min         1.00000      15.000000       0.100000       0.500000
# 25%     53173.50000      33.000000       2.570000       1.250000
# 50%    106346.00000      52.000000       5.040000       2.000000
# 75%    159518.50000      71.000000       7.520000       2.750000
# max    212691.00000      89.000000      10.000000       3.500000
#
#             T4_Level    Nodule_Size
# count  212691.000000  212691.000000
# mean        8.246204       2.503403
# std         2.164188       1.444631
# min         4.500000       0.000000
# 25%         6.370000       1.250000
# 50%         8.240000       2.510000
# 75%        10.120000       3.760000
# max        12.000000       5.000000

# %% [markdown]
# # Plots

# %% [markdown]
# # Bar_Plot

# %%
import matplotlib.pyplot as plt
thyroid_cancer_risk_counts = df.groupby(['Gender', 'Thyroid_Cancer_Risk']).size().unstack()
thyroid_cancer_risk_counts.plot(kind='bar',figsize=(10,5))
plt.title('Thyroid Cancer Risk by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Thyroid Cancer Risk')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(df['Ethnicity'].head(50),df['Thyroid_Cancer_Risk'].head(50))
plt.title('Ethnicity vs Thyroid_Cancer_Risk')
plt.xlabel('Ethnicity')
plt.ylabel('Thyroid_Cancer_Risk')
#plt.legend(title='Thyroid Cancer Risk')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))  # Optional: make the plot larger
plt.bar(df['Ethnicity'].head(10), df['Thyroid_Cancer_Risk'].head(10))
plt.title('Ethnicity vs Thyroid Cancer Risk')
plt.xlabel('Ethnicity')
plt.ylabel('Thyroid Cancer Risk')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to avoid label cutoff
plt.show()

# %% [markdown]
# # HeatMap

# %%
import seaborn as sns
data = {'Age': [66, 29, 86, 75, 35],
        'TSH_Level': [9.37, 1.83, 6.26, 4.10, 9.10],
        'T3_Level': [1.67, 1.73, 2.59, 2.62, 2.11],
        'T4_Level': [6.16, 10.54, 10.57, 11.04, 10.71],
        'Nodule_Size': [1.08, 4.05, 4.61, 2.46, 2.11]
}
df = pd.DataFrame(data)

#  correlation matrix
corr = df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Thyroid Dataset Features')
plt.show()

# %% [markdown]
# # Line Plot

# %%
import matplotlib.pyplot as plt
plt.plot(df['Age'].head(10), df['T3_Level'].head(10), color='green', marker='o')
plt.title('T3 Level Across First 100 Patients')
plt.xlabel('Age')
plt.ylabel('T3 Level')
plt.grid(True)                       
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df['Age'].head(10), df['Thyroid_Cancer_Risk'].head(10), color='green', marker='o')
plt.title('T3 Level Across First 100 Patients')
plt.xlabel('Age')
plt.ylabel('Thyroid_Cancer_Risk')
plt.grid(True)                       
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df['Ethnicity'].head(50), df['Thyroid_Cancer_Risk'].head(50), color='green', marker='o')
plt.title('Ethnicity vs Thyroid_Cancer_Risk')
plt.xlabel('Ethnicity')
plt.ylabel('Thyroid_Cancer_Risk')
plt.grid(True)                       
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df['Gender'].head(10), df['Thyroid_Cancer_Risk'].head(10), color='green', marker='o')
plt.title('Gender vs Thyroid_Cancer_Risk')
plt.xlabel('Gender')
plt.ylabel('Thyroid_Cancer_Risk')
plt.grid(True)                       
plt.show()

# %% [markdown]
# # Histogram Plot

# %%
data = { 'Age': [66, 29, 86, 75, 35, 58, 89, 72, 85, 46],
         'TSH_Level': [9.37, 1.83, 6.26, 4.10, 9.10, 2.00, 9.77, 7.72, 5.62, 5.60],
         'T3_Level': [1.67, 1.73, 2.59, 2.62, 2.11, 0.64, 3.25, 2.44, 2.53, 2.73],
         'Nodule_Size': [1.08, 4.05, 4.61, 2.46, 2.11, 1.48, 4.46, 2.36, 1.54, 2.53]
}
df = pd.DataFrame(data)
fig, axs = plt.subplots(2,2, figsize=(10, 10))  #Creates a 2x2 grid of subplots — a total of 4 individual plots (axes) arranged in 2 rows and 2 columns.
                                                #10,10=10 inches wide and 10 inches tall
axs[0, 0].hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
axs[0, 0].set_title('Age Distribution')
axs[0, 0].set_xlabel('Age')
axs[0, 0].set_ylabel('Frequency')

axs[0, 1].hist(df['TSH_Level'], bins=10, color='lightgreen', edgecolor='black')
axs[0, 1].set_title('TSH Level Distribution')
axs[0, 1].set_xlabel('TSH Level')
axs[0, 1].set_ylabel('Frequency')

axs[1, 0].hist(df['T3_Level'], bins=10, color='salmon', edgecolor='black')
axs[1, 0].set_title('T3 Level Distribution')
axs[1, 0].set_xlabel('T3 Level')
axs[1, 0].set_ylabel('Frequency')

axs[1, 1].hist(df['Nodule_Size'], bins=10, color='plum', edgecolor='black')
axs[1, 1].set_title('Nodule Size Distribution')
axs[1, 1].set_xlabel('Nodule Size')
axs[1, 1].set_ylabel('Frequency')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Box Plot

# %%
numeric_cols = ['Age', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size']
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[numeric_cols])
plt.title('Box Plot of Thyroid Dataset Numerical Features')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # Pair Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {'Age': [66, 29, 86, 75, 35],
        'TSH_Level': [9.37, 1.83, 6.26, 4.10, 9.10],
        'T3_Level': [1.67, 1.73, 2.59, 2.62, 2.11],
        'T4_Level': [6.16, 10.54, 10.57, 11.04, 10.71],
        'Nodule_Size': [1.08, 4.05, 4.61, 2.46, 2.11],
        'Thyroid_Cancer_Risk': ['Low', 'Low', 'Low', 'Medium', 'High']}
df = pd.DataFrame(data)
# Optional: Convert 'Thyroid_Cancer_Risk' to category if needed
df['Thyroid_Cancer_Risk'] = pd.Categorical(df['Thyroid_Cancer_Risk'], categories=['Low', 'Medium', 'High'], ordered=True)
sns.pairplot(df, vars=['Age', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size'], hue='Thyroid_Cancer_Risk')
plt.suptitle("Pair Plot of Thyroid Dataset Features Colored by Cancer Risk", y=1.02)
plt.show()

# %% [markdown]
# # Pie Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
Diagnosis_counts = df['Diagnosis'].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(Diagnosis_counts, labels=Diagnosis_counts.index, autopct='%1.2f%%', startangle=140, colors=['lightgreen', 'salmon'])
plt.title('Distribution of Thyroid Cancer Diagnosis')
plt.show()
